# %% [markdown]
# ## Install dependancies

# %%
import cv2
import albumentations as A
import matplotlib.pyplot as plt
import shutil
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from PIL import Image
import os
import numpy as np

# %% [markdown]
# ## Create Train and Val Set

# %%
val_image_path = 'data/valid/images'
val_label_path = 'data/valid/labels'

os.makedirs(val_image_path, exist_ok = True)
os.makedirs(val_label_path, exist_ok = True)

# Val set: 7% of the total images
thresh = int(0.07 * len(os.listdir('data/images/')))
cnt =0 

#Loop through images in the dataset
for (root, dirs, files) in os.walk('data/images/'):
    if root.endswith('data') or root.endswith('Store'):
        continue
    else:
        np.random.shuffle(files)
        
        for image in files:
            if cnt == thresh:
                break
                
            if not image.endswith('Store'):
                shutil.copy(os.path.join(root, image),  val_image_path)
                os.remove(os.path.join(root, image))
                shutil.copy(os.path.join(root.split('/')[0], 'labels', image.replace('.jpg', '.txt')), val_label_path)
                os.remove(os.path.join(root.split('/')[0], 'labels', image.replace('.jpg', '.txt')))
                cnt += 1

# %% [markdown]
# ## Define augmentation pipeline

# %%
aug = A.Compose([A.OneOf([A.RandomBrightnessContrast(brightness_limit=[-0.15,0.30], contrast_limit=[-0.08,0.25], brightness_by_max=False,always_apply=True, p=0.9),
                                A.RandomToneCurve(scale=0.3, always_apply=True, p=0.9),
                                A.RGBShift(r_shift_limit=9, g_shift_limit=7, b_shift_limit=10, p=0.9),
                                A.ChannelDropout(p = 1.0),
                                A.ToGray(p=0.9),
                                A.ChannelShuffle(p = 0.9),
                                A.Blur(blur_limit =3, p = 0.8),
                                A.ColorJitter(brightness = 0.2, contrast = 0.2, saturation = 0.2, hue = 0.7)], p = 1.0)])

# %% [markdown]
# #### Augment each image twice and write to disk along with the labels

# %%
cnt = 0

#Loop through the images of train set
for (root, dirs, files) in os.walk('final_dataset/train/images'):
    for img_path in files:
        
        if not img_path.endswith('Store'):
            image = cv2.imread(os.path.join(root, img_path))
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            #perform 2 augmentations for each image
            for i in range(2):
                aug_img = aug(image = image)['image']
                aug_name = f"{img_path.split('.')[0]}_aug{i}.jpg"
                
                #Write the augmented image to image folder
                cv2.imwrite(os.path.join(root, aug_name), aug_img)
                
                #define source and destination of yolo's label file
                label_source = os.path.join('/'.join(root.split('/')[:-1]) , 'labels', img_path.replace('.jpg', '.txt'))
                label_dest  = os.path.join('/'.join(root.split('/')[:-1]) , 'labels', aug_name.replace('.jpg', '.txt'))
                shutil.copyfile(label_source, label_dest)
                
        #prints after every 100 images         
        cnt += 1
        if cnt%100==0:
            print(f'{cnt} images done')

# %% [markdown]
# ## Training

# %% [markdown]
# #### Define paths

# %%
project_path = "/content/drive/MyDrive/car_classification/"
yolo_path = project_path + 'yolov5/'

# %% [markdown]
# #### Clone yolo repo and install dependancies

# %%
# Clone the yolov5 Repo
# %cd {project_path}
# !git clone https://github.com/ultralytics/yolov5.git

#Move the dataset inside yolo folder
# !mv final_dataset.zip yolov5

# %cd {yolo_path}
# !pip install -r requirements.txt
# !pip install wandb

#unzip the dataset
# !unzip final_dataset.zip

# %% [markdown]
# #### Train yolov5 model
# * Model used: ```yolov5m```
# * Optimizer: ```SGD```

# %%
# %cd {yolo_path}
# !python train.py --img 640 --batch 32 --epochs 100 --data ./final_dataset/data.yaml --weights yolov5m --cache  --name "yolov5medium"

# %% [markdown]
# #### Train yolov5 model
# * Model used: best weights from ```yolov5m``` training
# * Freeze Backbone

# %%
# %cd {yolo_path}

# !python train.py --img 640 --batch 32 --epochs 30 --data ./final_dataset/data.yaml --weights runs/train/yolov5medium2/weights/best.pt --cache --freeze 10 --name "yolov5med_head_frozen"
# Out:
# /content/drive/MyDrive/car_classification/yolov5

# %% [markdown]
# #### Train yolov5 model
# * Model used: ```yolov5s```

# %%
# %cd {yolo_path}
# !python train.py --img 640 --batch 32 --epochs 100 --data ./final_dataset/data.yaml --weights yolov5s.pt --cache --name "yolov5small"
# Out:
# wandb: Currently logged in as: sumitkutty (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=./final_dataset/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5small, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-197-g0cf932b torch 1.10.0+cu111 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Tracking run with wandb version 0.12.9
# wandb: Syncing run yolov5small
# wandb: ⭐️ View project at https://wandb.ai/sumitkutty/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/sumitkutty/YOLOv5/runs/2voovnzz
# wandb: Run data is saved locally in /content/drive/MyDrive/car_classification/yolov5/wandb/run-20220119_095115-2voovnzz
# wandb: Run `wandb offline` to turn off syncing.
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7025023 parameters, 7025023 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning 'final_dataset/train/labels.cache' images and labels... 6249 found, 0 missing, 0 empty, 0 corrupt: 100% 6249/6249 [00:00<?, ?it/s]
# train: Caching images (5.4GB ram): 100% 6249/6249 [00:26<00:00, 234.01it/s]
# val: Scanning 'final_dataset/valid/labels.cache' images and labels... 156 found, 0 missing, 0 empty, 0 corrupt: 100% 156/156 [00:00<?, ?it/s]
# val: Caching images (0.1GB ram): 100% 156/156 [00:02<00:00, 77.23it/s]
# Plotting labels to runs/train/yolov5small2/labels.jpg...
#
# AutoAnchor: 4.70 anchors/target, 0.999 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/yolov5small2
# Starting training for 100 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/99     6.81G   0.07944   0.07043    0.0172       199       640: 100% 196/196 [00:35<00:00,  5.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.62it/s]
#                  all        156       1165      0.587      0.542      0.553      0.237
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/99     8.74G   0.05999   0.06586  0.007641        98       640: 100% 196/196 [00:33<00:00,  5.78it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.08it/s]
#                  all        156       1165       0.58       0.59      0.567      0.244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/99     8.74G    0.0576   0.06443  0.006923       118       640: 100% 196/196 [00:32<00:00,  6.01it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  3.99it/s]
#                  all        156       1165      0.685      0.634      0.648      0.322
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/99     8.74G   0.05558   0.06488  0.006706       124       640: 100% 196/196 [00:31<00:00,  6.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.44it/s]
#                  all        156       1165       0.78      0.589      0.643      0.318
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/99     8.74G    0.0532   0.06673   0.00664       131       640: 100% 196/196 [00:31<00:00,  6.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.14it/s]
#                  all        156       1165      0.738       0.57       0.62      0.305
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       5/99     8.74G   0.05195   0.06839  0.006512       143       640: 100% 196/196 [00:31<00:00,  6.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.34it/s]
#                  all        156       1165      0.687      0.559      0.599      0.298
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       6/99     8.74G   0.05031   0.06622  0.006166       124       640: 100% 196/196 [00:31<00:00,  6.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.34it/s]
#                  all        156       1165      0.698      0.571      0.605        0.3
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       7/99     8.74G   0.04932   0.06547  0.005815        97       640: 100% 196/196 [00:31<00:00,  6.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.49it/s]
#                  all        156       1165      0.754      0.559      0.619      0.311
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       8/99     8.74G   0.04843   0.06426  0.005568       104       640: 100% 196/196 [00:31<00:00,  6.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.21it/s]
#                  all        156       1165      0.718        0.6       0.63      0.322
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       9/99     8.74G   0.04805   0.06423  0.005368       148       640: 100% 196/196 [00:31<00:00,  6.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:02<00:00,  1.27it/s]
#                  all        156       1165      0.707      0.571       0.61      0.301
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      10/99     8.74G   0.04749   0.06335  0.005118       124       640: 100% 196/196 [00:31<00:00,  6.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:00<00:00,  4.52it/s]
#                  all        156       1165      0.712      0.602      0.633      0.318
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      11/99
/weights/last.pt, 14.5MB
# Optimizer stripped from runs/train/yolov5small2/weights/best.pt, 14.5MB
#
# Validating runs/train/yolov5small2/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:03<00:00,  1.29s/it]
#                  all        156       1165      0.743      0.612      0.643      0.356
#               person        156        749      0.683      0.609      0.618      0.306
#                  car        156        416      0.802      0.615      0.669      0.406
#
# wandb: Waiting for W&B process to finish, PID 5360... (success).
# wandb:
# wandb: Run history:
# wandb:        metrics/mAP_0.5 ▁█▄▆▇▅▆▆▇▆▆▇█▇█▇▆▇▇▇▇▇█▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇█
# wandb:   metrics/mAP_0.5:0.95 ▁▆▅▅▆▅▆▆▇▇▇▇▇▇█▇▆▇▇▇▇█████▇▇▇████▇██████
# wandb:      metrics/precision ▁▄▄▆▅▆▅▆▆▆▆▇▅▆▆▇▆▇▇▆█▆▇▇▆█▇▆▆█▇▇█▇▆▇▇▇▇▆
# wandb:         metrics/recall ▁█▂▂▆▂▆▄▄▄▅▆▇▆▅▃▄▄▅▇▄▅▅▅▆▃▄▄▅▃▅▄▃▃▄▄▄▄▄▆
# wandb:         train/box_loss █▅▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/cls_loss █▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/obj_loss █▇█▇▆▆▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁
# wandb:           val/box_loss █▂▂▂▁▂▂▂▂▁▁▂▁▁▁▁▂▂▂▂▃▃▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:           val/cls_loss ▄▁▄▂▃▃▂▃▃▁▃▂▃▄▁▃▅▃▆▄▅▇█▇▇█▇▆▆▆▇▇▆▇▇▇▇██▇
# wandb:           val/obj_loss ▁▁▃▃▃▃▃▃▄▃▄▃▃▄▅▄▅▅▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇██████▆
# wandb:                  x/lr0 ▂▅██████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:                  x/lr1 ▂▅██████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:                  x/lr2 █▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:             best/epoch 61
# wandb:           best/mAP_0.5 0.64283
# wandb:      best/mAP_0.5:0.95 0.35592
# wandb:         best/precision 0.75321
# wandb:            best/recall 0.60516
# wandb:        metrics/mAP_0.5 0.6435
# wandb:   metrics/mAP_0.5:0.95 0.35614
# wandb:      metrics/precision 0.74279
# wandb:         metrics/recall 0.6121
# wandb:         train/box_loss 0.03075
# wandb:         train/cls_loss 0.00217
# wandb:         train/obj_loss 0.03914
# wandb:           val/box_loss 0.05064
# wandb:           val/cls_loss 0.00844
# wandb:           val/obj_loss 0.05214
# wandb:                  x/lr0 0.00101
# wandb:                  x/lr1 0.00101
# wandb:                  x/lr2 0.00101
# wandb:
# wandb: Synced 5 W&B file(s), 337 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Synced yolov5small: https://wandb.ai/sumitkutty/YOLOv5/runs/2voovnzz
# wandb: Find logs at: ./wandb/run-20220119_095115-2voovnzz/logs/debug.log
# wandb:
# Results saved to runs/train/yolov5small2

# %% [markdown]
# #### Train yolov5 model
# * Further train by using the weights of ```yolov5m```
# * Optimizer: ```Adam```
# * Epochs: ```50```

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data ./final_dataset/data.yaml --weights runs/train/yolov5medium2/weights/best.pt --optimizer 'Adam' --cache --name "yolov5medcontinued"

# %% [markdown]
# #### Train yolov5 model
# * Further train by using the weights of ```yolov5medcontinued```
# * Optimizer: ```Adam```
# * Epochs: ```50```
# * Freeze the network
#
# **Achieved the best result**

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data ./final_dataset/data.yaml --weights runs/train/yolov5medcontinued2/weights/best.pt --optimizer 'Adam' --cache --name "yolov5medcontinued-froznet" --freeze 24

# %% [markdown]
# #### Perform Inference on val set
# * Model used: best weight ```yolov5medcontinued-froznet```
# * conf_thresh = 0.25

# %%
# %cd {yolo_path}
# !python detect.py --weights runs/train/yolov5medcontinued-froznet/weights/best.pt --img 640 --conf 0.3 --source ./final_dataset/valid/images
# Out:
# detect: weights=['runs/train/yolov5medium2/weights/best.pt'], source=./final_dataset/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-197-g0cf932b torch 1.10.0+cu111 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20856975 parameters, 0 gradients, 48.0 GFLOPs
# image 1/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000005.jpg: 608x640 10 persons, 1 car, Done. (0.020s)
# image 2/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000010.jpg: 448x640 1 person, Done. (0.048s)
# image 3/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000013.jpg: 480x640 17 persons, 4 cars, Done. (0.046s)
# image 4/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000020.jpg: 480x640 2 persons, 1 car, Done. (0.043s)
# image 5/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000026.jpg: 640x480 2 persons, Done. (0.022s)
# image 6/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000030.jpg: 448x640 3 persons, 4 cars, Done. (0.043s)
# image 7/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000032.jpg: 480x640 5 persons, 3 cars, Done. (0.043s)
# image 8/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000065.jpg: 448x640 17 persons, 1 car, Done. (0.042s)
# image 9/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000073.jpg: 640x448 1 person, 1 car, Done. (0.023s)
# image 10/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000091.jpg: 384x640 1 person, 1 car, Done. (0.045s)
# image 11/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000100.jpg: 480x640 1 person, 1 car, Done. (0.042s)
# image 12/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000117.jpg: 640x640 1 person, 1 car, Done. (0.013s)
# image 13/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000129.jpg: 448x640 3 persons, 7 cars, Done. (0.040s)
# image 14/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000137.jpg: 480x640 1 person, 6 cars, Done. (0.041s)
# image 15/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000152.jpg: 448x640 1 car, Done. (0.041s)
# image 16/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000183.jpg: 480x640 2 persons, 4 cars, Done. (0.041s)
# image 17/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000199.jpg: 480x640 5 persons, 1 car, Done. (0.041s)
# image 18/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000223.jpg: 480x640 2 persons, 3 cars, Done. (0.041s)
# image 19/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000234.jpg: 480x640 3 persons, 3 cars, Done. (0.041s)
# image 20/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000243.jpg: 448x640 9 persons, 3 cars, Done. (0.041s)
# image 21/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000244.jpg: 448x640 6 persons, 1 car, Done. (0.040s)
# image 22/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000248.jpg: 480x640 6 persons, 2 cars, Done. (0.041s)
# image 23/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000260.jpg: 480x640 20 persons, 3 cars, Done. (0.041s)
# image 24/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000272.jpg: 448x640 2 persons, 1 car, Done. (0.041s)
# image 25/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000279.jpg: 448x640 3 persons, 3 cars, Done. (0.041s)
# image 26/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000289.jpg: 480x640 2 persons, 1 car, Done. (0.041s)
# image 27/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000353.jpg: 640x480 2 persons, 1 car, Done. (0.016s)
# image 28/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000364.jpg: 640x640 1 person, 2 cars, Done. (0.013s)
# image 29/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000419.jpg: 480x640 4 persons, 2 cars, Done. (0.041s)
# image 30/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000430.jpg: 288x640 1 person, 1 car, Done. (0.043s)
# image 31/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000441.jpg: 448x640 4 persons, 4 cars, Done. (0.041s)
# image 32/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000504.jpg: 448x640 2 persons, 1 car, Done. (0.041s)
# image 33/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000000507.jpg: 416x640 6 persons, 3 cars, Done. (0.044s)
# image 34/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000
156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001688.jpg: 320x640 3 persons, Done. (0.040s)
# image 117/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001696.jpg: 448x640 2 persons, 1 car, Done. (0.041s)
# image 118/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001697.jpg: 480x640 8 persons, 1 car, Done. (0.041s)
# image 119/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001708.jpg: 480x640 1 person, 2 cars, Done. (0.040s)
# image 120/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001710.jpg: 448x640 2 persons, 1 car, Done. (0.041s)
# image 121/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001720.jpg: 512x640 3 persons, Done. (0.042s)
# image 122/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001729.jpg: 448x640 7 persons, 1 car, Done. (0.041s)
# image 123/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001740.jpg: 480x640 11 persons, 3 cars, Done. (0.041s)
# image 124/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001754.jpg: 640x448 Done. (0.016s)
# image 125/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001767.jpg: 448x640 5 persons, 3 cars, Done. (0.040s)
# image 126/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001806.jpg: 480x640 7 persons, 6 cars, Done. (0.041s)
# image 127/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001811.jpg: 480x640 1 person, 3 cars, Done. (0.041s)
# image 128/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001823.jpg: 448x640 1 person, 3 cars, Done. (0.040s)
# image 129/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001867.jpg: 448x640 5 persons, 4 cars, Done. (0.042s)
# image 130/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001874.jpg: 480x640 2 persons, 2 cars, Done. (0.041s)
# image 131/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001898.jpg: 480x640 1 person, 4 cars, Done. (0.040s)
# image 132/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001922.jpg: 640x640 1 person, Done. (0.014s)
# image 133/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001924.jpg: 480x640 7 persons, 1 car, Done. (0.041s)
# image 134/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001929.jpg: 640x448 1 person, 1 car, Done. (0.026s)
# image 135/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001942.jpg: 416x640 3 persons, 1 car, Done. (0.043s)
# image 136/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001959.jpg: 480x640 5 persons, 1 car, Done. (0.041s)
# image 137/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001961.jpg: 448x640 1 person, Done. (0.041s)
# image 138/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000001965.jpg: 640x480 1 person, 2 cars, Done. (0.016s)
# image 139/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002001.jpg: 480x640 1 person, 3 cars, Done. (0.040s)
# image 140/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002018.jpg: 448x640 1 person, 2 cars, Done. (0.040s)
# image 141/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002019.jpg: 448x640 2 persons, 1 car, Done. (0.042s)
# image 142/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002023.jpg: 480x640 7 persons, 1 car, Done. (0.041s)
# image 143/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002032.jpg: 640x640 4 persons, 1 car, Done. (0.014s)
# image 144/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002044.jpg: 480x640 3 persons, 4 cars, Done. (0.041s)
# image 145/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002058.jpg: 480x640 1 car, Done. (0.041s)
# image 146/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002060.jpg: 448x640 1 person, 1 car, Done. (0.041s)
# image 147/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002070.jpg: 640x512 1 person, 1 car, Done. (0.021s)
# image 148/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002082.jpg: 480x640 1 person, 2 cars, Done. (0.041s)
# image 149/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002133.jpg: 512x640 8 persons, 6 cars, Done. (0.041s)
# image 150/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002134.jpg: 480x640 1 person, 2 cars, Done. (0.041s)
# image 151/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002161.jpg: 384x640 1 person, 1 car, Done. (0.040s)
# image 152/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002175.jpg: 448x640 2 persons, 1 car, Done. (0.041s)
# image 153/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002177.jpg: 480x640 11 persons, 2 cars, Done. (0.041s)
# image 154/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002185.jpg: 448x640 8 persons, 3 cars, Done. (0.040s)
# image 155/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002198.jpg: 480x640 7 persons, 10 cars, Done. (0.041s)
# image 156/156 /content/drive/MyDrive/car_classification/yolov5/final_dataset/valid/images/image_000002232.jpg: 448x640 3 persons, 2 cars, Done. (0.041s)
# Speed: 0.6ms pre-process, 36.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# ## THE END
